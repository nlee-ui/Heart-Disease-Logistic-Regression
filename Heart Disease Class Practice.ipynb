# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('heartPG.csv')
df.head()
# Out:
#    Unnamed: 0  age     sex  rest_bp  chol  fbs  max_hr  exang  old_peak  \
# 0           0   63    Male      145   233    1     150      0       2.3
# 1           1   67    Male      160   286    0     108      1       1.5
# 2           2   67    Male      120   229    0     129      1       2.6
# 3           3   37    Male      130   250    0     187      0       3.5
# 4           4   41  Female      130   204    0     172      0       1.4
#
#    slope   ca  disease
# 0      3  0.0        0
# 1      2  3.0        1
# 2      2  2.0        1
# 3      3  0.0        0
# 4      1  0.0        0

# %%
#EDA - Shows the datatypes, 32 columns, 569 rows
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   age         303 non-null    int64
#  2   sex         303 non-null    str
#  3   rest_bp     303 non-null    int64
#  4   chol        303 non-null    int64
#  5   fbs         303 non-null    int64
#  6   max_hr      303 non-null    int64
#  7   exang       303 non-null    int64
#  8   old_peak    303 non-null    float64
#  9   slope       303 non-null    int64
#  10  ca          299 non-null    float64
#  11  disease     303 non-null    int64
# dtypes: float64(2), int64(9), str(1)
# memory usage: 28.5 KB

# %%
#EDA - Statistical Summary of data
df.describe()
# Out:
#        Unnamed: 0         age     rest_bp        chol         fbs      max_hr  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   151.000000   54.438944  131.689769  246.693069    0.148515  149.607261
# std     87.612784    9.038662   17.599748   51.776918    0.356198   22.875003
# min      0.000000   29.000000   94.000000  126.000000    0.000000   71.000000
# 25%     75.500000   48.000000  120.000000  211.000000    0.000000  133.500000
# 50%    151.000000   56.000000  130.000000  241.000000    0.000000  153.000000
# 75%    226.500000   61.000000  140.000000  275.000000    0.000000  166.000000
# max    302.000000   77.000000  200.000000  564.000000    1.000000  202.000000
#
#             exang    old_peak       slope          ca     disease
# count  303.000000  303.000000  303.000000  299.000000  303.000000
# mean     0.326733    1.039604    1.600660    0.672241    0.458746
# std      0.469794    1.161075    0.616226    0.937438    0.499120
# min      0.000000    0.000000    1.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    0.000000    0.000000
# 50%      0.000000    0.800000    2.000000    0.000000    0.000000
# 75%      1.000000    1.600000    2.000000    1.000000    1.000000
# max      1.000000    6.200000    3.000000    3.000000    1.000000

# %%
Df = pd.DataFrame({'chol': df['chol'], 'rest_bp': df['rest_bp'], 'max_hr': df['max_hr'], 'age': df['age'], 'disease': df['disease']})
Df
# Out:
#      chol  rest_bp  max_hr  age  disease
# 0     233      145     150   63        0
# 1     286      160     108   67        1
# 2     229      120     129   67        1
# 3     250      130     187   37        0
# 4     204      130     172   41        0
# ..    ...      ...     ...  ...      ...
# 298   264      110     132   45        1
# 299   193      144     141   68        1
# 300   131      130     115   57        1
# 301   236      130     174   57        1
# 302   175      138     173   38        0
#
# [303 rows x 5 columns]

# %%
sns.heatmap(Df.corr(), annot = True, cmap = 'plasma')
# Out:
# <Axes: >
